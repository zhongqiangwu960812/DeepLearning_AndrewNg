# %%
# %matplotlib inline
# %run main.py
# Out:
# Please select the dataset as follows:
# 1 - > noisy_circles
# 2 - > noisy_moons
# 3 - > blobs
# 4 - > gaussian_quantiles
# 5 -> flower data
#
# Please input your answer(1, 2, 3,4, 5). q is quit : 4
# gaussian_quantiles
# Accuracy: 91%
#
# Please select the dataset as follows:
# 1 - > noisy_circles
# 2 - > noisy_moons
# 3 - > blobs
# 4 - > gaussian_quantiles
# 5 -> flower data
#
# Please input your answer(1, 2, 3,4, 5). q is quit : q
